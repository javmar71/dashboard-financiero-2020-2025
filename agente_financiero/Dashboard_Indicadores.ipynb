# %% [markdown]
# # Dashboard de Indicadores Financieros 2021-2025
# Este notebook consolida los 65 indicadores calculados automáticamente y proporciona una vista de control para la toma de decisiones.

# %%
import pandas as pd
from IPython.display import display, HTML
import os

# Ruta del archivo consolidado generado en la fase anterior
base_dir = r'C:\Users\Usuario\Desktop\mi_proyecto_finanzas\AUTOMAT ANALISIS FIN\agente_financiero'
reporte_path = os.path.join(base_dir, 'REPORTE_FINAL_65_INDICADORES.csv')

# Cargar datos
df = pd.read_csv(reporte_path)

# Formato para visualización
html_style = """
<style>
.dark-table-card {background:#000;border-radius:10px;border:1px solid #333;margin-bottom:30px;overflow:hidden;}
.dataframe-scroll {max-height:600px;overflow-y:auto;background:#000;}
th {background-color: #121212 !important; color: #fff !important;}
td {color: #e0e0e0 !important;}
</style>
"""

display(HTML(html_style))
display(HTML("<div class='dark-table-card'><div class='dataframe-scroll"> + df.to_html(classes='table table-dark', index=False) + "</div></div>"))
